# %% [markdown]
# # Practice 2
#
# > 데이터 & 제어문

# %% [markdown]
# ## 더블더블 (SWEA #2019 변형)
#
# > 자연수 number를 입력 받아, 1부터 주어진 자연수 number까지 홀수는 2, 짝수는 3을 곱한 값(들)을 출력하시오.
#
# ---
# ```
# [제약 사항]
# 주어질 숫자는 30을 넘지 않는다.
#
# [입력 예시]
# 5
#
# [출력 예시]
# 36
# ```

# %%
number = int(input())

# 아래에 코드를 작성하시오.
total = 0
for n in range(1, number+1):
  if n % 2 == 0:
    total += n*3
  else:
    total += n*2
print(total)
# Out:
# 5
# 36

# %% [markdown]
# ## 간단한 소수 판별 1
#
# > 입력으로 1개의 정수 number가 주어진다. 정수 number가 소수인지 아닌지 판별하여 출력하시오.
#
# ---
# ```
# [제약사항]
# number는 2이상 1,000이하의 정수이다. (2 ≤ number ≤ 1,000)
#
# [입력]
# 입력으로 정수 number가 주어진다.
#
# [출력]
# 정수 number가 소수이면 'Y', 소수가 아니면 'N'을 출력한다.
# ```

# %%
number = int(input())

# 아래에 코드를 작성하시오.
a = []
for n in range(1, number+1):
  if number % n == 0:
    a.append(n)

print('Y') if len(a) == 2 else print('N')
# Out:
# 198
# N

# %% [markdown]
# ## 간단한 소수 판별 2
#
# > 조건, 반복문을 응용하여 numbers 리스트의 요소들이 소수인지 아닌지 판단하는 코드를 작성하시오.
#
# ---
# ```
# [출력 예시]
# 26은(는) 소수가 아닙니다. 2은(는) 26의 인수입니다.
# 39은(는) 소수가 아닙니다. 3은(는) 39의 인수입니다.
# 51은(는) 소수가 아닙니다. 3은(는) 51의 인수입니다.
# 53은(는) 소수입니다.
# 57은(는) 소수가 아닙니다. 3은(는) 57의 인수입니다.
# 79은(는) 소수입니다.
# 85은(는) 소수가 아닙니다. 5은(는) 85의 인수입니다.
# ```

# %%
numbers = [26, 39, 51, 53, 57, 79, 85]

# 아래에 코드를 작성하시오.
for number in numbers:
  a = []
  b = []
  for n in range(1, number+1):
    if number % n == 0:
      a.append(n)
  print(f'{number}은(는) 소수입니다.') if len(a) == 2 else print(f'{number}은(는) 소수가 아닙니다. {a[1]}은(는) {number}의 인수입니다.')
# Out:
# 26은(는) 소수가 아닙니다. 2은(는) 26의 인수입니다.
# 39은(는) 소수가 아닙니다. 3은(는) 39의 인수입니다.
# 51은(는) 소수가 아닙니다. 3은(는) 51의 인수입니다.
# 53은(는) 소수입니다.
# 57은(는) 소수가 아닙니다. 3은(는) 57의 인수입니다.
# 79은(는) 소수입니다.
# 85은(는) 소수가 아닙니다. 5은(는) 85의 인수입니다.
